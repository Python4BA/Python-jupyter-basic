# %% [markdown]
# # Chapter 2 – Variables & Simple Data Types #

# %% [markdown]
# ## Variables ##

# %% [markdown]
# Variable = label pointing to a value, not a storage box
#
# Must be defined before use → NameError if not
#
# Python executes top to bottom
#
# Case-sensitive: age ≠ Age

# %%
x = 5
print(x)   # ✅ works
# Out:
# 5

# %% [markdown]
# ## Strings ##

# %% [markdown]
# Strings are immutable → methods return new string
#
# .replace() does not change original → must assign
#
# Quotes: " " or ' ' both valid
#
# f-strings required for {} interpolation

# %%
msg = "hello"
msg.replace("h", "H")   # returns "Hello" but msg still "hello"
msg = msg.replace("h", "H")   # ✅ msg updated

# %% [markdown]
# ## Numbers ##

# %% [markdown]
# Integers: whole numbers → 5, -3
#
# Floats: decimals → 3.14, -2.5
#
# / → float division → 5/2 = 2.5
#
# // → floor division → 5//2 = 2
#
# % → remainder → 5%2 = 1
#
# Mixing int + float → result is float → 2 + 3.0 = 5.0

# %%
"5" + "5"   # "55"
5 + 5       # 10
# Out:
# 10

# %% [markdown]
# ## Conversion ##

# %% [markdown]
# int(3.9) → 3 (truncates, not rounds)
#
# float(5) → 5.0
#
# round(3.9) → 4

# %% [markdown]
# ## ⚡ Common Errors ##

# %% [markdown]
# NameError → variable not defined
#
# TypeError → mixing incompatible types (e.g., str + int)
#
# ValueError → invalid conversion (e.g., int("abc"))

# %% [markdown]
# ## ✅ Quick Revision Snippet ##

# %% [markdown]
# Variables:
# - Label, not storage
# - Must exist before use
# - Case-sensitive
#
# Naming:
# - No spaces, no starting number
# - Use underscore
# - age ≠ Age
#
# Strings:
# - Immutable
# - replace() returns new string
# - f-string needed for {}
#
# Numbers:
# - / → float
# - // → floor division
# - % → remainder
# - "5" + "5" = "55"
#
# Conversion:
# - int(3.9) → 3
# - float(5) → 5.0
# - round(3.9) → 4
#
# Comments:
# - ## ignored
# - Explain logic, not obvious code
#
# Errors:
# - NameError, TypeError, ValueError

# %% [markdown]
# ## 🧘 The Zen of Python (PEP 20) ##
#
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren’t special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one — and preferably only one — obvious way to do it.
#
# Although that way may not be obvious at first unless you’re Dutch.
#
# Now is better than never.
#
# Although never is often better than right now.
#
# If the implementation is hard to explain, it’s a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea — let’s do more of those!

# %%
import os
os.chdir(r"C:\Users\nadee\Documents\Python\Python crase course\Chapter 2 – Variables & Simple Data Types")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nadee\\Documents\\Python\\Python crase course\\Chapter 2 – Variables & Simple Data Types'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nadee\\Documents\\Python\\Python crase course\\Chapter 2 – Variables & Simple Data Types'

# %%
os.listdir()
# Out:
# ['.chapter2.ipynb.layout']
